# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\markd\hamilton-county-homes-scraper-main\data\raw\downloads\historical_sales'
os.chdir(path)
files = os.listdir()

# %%
historical = pd.read_excel('HistoricSalesExport.xlsx')

# %%
cols = ["parcel_number",
  "use_code",
  "number_of_parcels",
  "conveyance_number",
  "owner_name_1",
  "owner_name_2",
  "owner_address_1",
  "owner_address_2",
  "date_of_sale",
  "instrument_type",
  "appraisal_area",
  "previous_owner",
  "total_sales_records",
  "sale_price",
  "transfer_type",
  "street_direction",
  "house_number",
  "street_name",
  "street_suffix",
  "city",
  "state",
  "zip",
  "subdivision",
  "tax_year",
  "style",
  "grade",
  "exterior_wall_type",
  "basement",
  "heating",
  "air_conditioning",
  "total_rooms",
  "full_bath",
  "half_bath",
  "fireplaces",
  "garage_type",
  "garage_capacity",
  "num_stories",
  "year_built",
  "finished_sq_ft",
  "total_finish_area",
  "first_floor_area",
  "half_floor_area",
  "finished_basement" 
]

# %%
integers = [
    "number_of_parcels",
  "total_sales_records",
  "total_rooms",
  "full_bath",
  "half_bath",
  "fireplaces",
  "garage_capacity",
  "year_built"
  ]

# %%
historical[integers] = historical[integers].astype('Int64')

# %%
historical[cols].to_csv("historical.csv",index=False)
